# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('India-disability-data(cleaned).csv')

# %%
df.head()
# Out:
#    State Code Area Name Total/ Rural/Urban Disability       Age-group  \
# 0           0     INDIA              Total      Total           Total
# 1           0     INDIA              Total      Total            0-14
# 2           0     INDIA              Total      Total           15-59
# 3           0     INDIA              Total      Total             60+
# 4           0     INDIA              Total      Total  Age not stated
#
#    Total disabled population - Persons  Total disabled population - Males  \
# 0                             26814994                           14988593
# 1                              5572336                            3073214
# 2                             15728243                            9125226
# 3                              5376619                            2713995
# 4                               137796                              76158
#
#    Total disabled population - Females  Main worker - Persons  \
# ...

# %%
#DATA PROCESSING

# %%
df = df[df['Area Name'] != 'INDIA'] 
df = df[df['Total/ Rural/Urban'] != 'Total']
df = df[df['Disability'] != 'Total']
df = df[df['Age-group'] != 'Total']
df.head()
# Out:
#      State Code                     Area Name Total/ Rural/Urban  Disability  \
# 186           1  State - JAMMU & KASHMIR (01)              Rural   In-Seeing
# 187           1  State - JAMMU & KASHMIR (01)              Rural   In-Seeing
# 188           1  State - JAMMU & KASHMIR (01)              Rural   In-Seeing
# 189           1  State - JAMMU & KASHMIR (01)              Rural   In-Seeing
# 191           1  State - JAMMU & KASHMIR (01)              Rural  In-Hearing
#
#           Age-group  Total disabled population - Persons  \
# 186            0-14                                10502
# 187           15-59                                23093
# 188             60+                                16496
# 189  Age not stated                                   51
# 191            0-14                                12461
#
#      Total disabled population - Males  Total disabled population - Females  \
# 186                               5720                                 4782
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#       State Code                               Area Name Total/ Rural/Urban  \
# 0              1            State - JAMMU & KASHMIR (01)              Rural
# 1              1            State - JAMMU & KASHMIR (01)              Rural
# 2              1            State - JAMMU & KASHMIR (01)              Rural
# 3              1            State - JAMMU & KASHMIR (01)              Rural
# 4              1            State - JAMMU & KASHMIR (01)              Rural
# ...          ...                                     ...                ...
# 2235          35  State - ANDAMAN & NICOBAR ISLANDS (35)              Urban
# 2236          35  State - ANDAMAN & NICOBAR ISLANDS (35)              Urban
# 2237          35  State - ANDAMAN & NICOBAR ISLANDS (35)              Urban
# 2238          35  State - ANDAMAN & NICOBAR ISLANDS (35)              Urban
# 2239          35  State - ANDAMAN & NICOBAR ISLANDS (35)              Urban
#
#                Disability       Age-group  \
# ...

# %%
# df['Area Name'] = df['Area Name'][1]

for i in range(0,len(df)):
    df['Area Name'][i] = df['Area Name'][i][8:-6]
df['Area Name'].value_counts()
# Out:
# C:\Users\Keerthana\AppData\Local\Temp\ipykernel_15588\3379998824.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area Name'][i] = df['Area Name'][i][8:-6]
# C:\Users\Keerthana\AppData\Local\Temp\ipykernel_15588\3379998824.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area Name'][i] = df['Area Name'][i][8:-6]
# C:\Users\Keerthana\AppData\Local\Temp\ipykernel_15588\3379998824.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# df = df.drop('Total disabled population - Persons', axis=1)
df = df.drop('State Code', axis=1)
df
# Out:
#                      Area Name Total/ Rural/Urban           Disability  \
# 0               JAMMU & KASHMI              Rural            In-Seeing
# 1               JAMMU & KASHMI              Rural            In-Seeing
# 2               JAMMU & KASHMI              Rural            In-Seeing
# 3               JAMMU & KASHMI              Rural            In-Seeing
# 4               JAMMU & KASHMI              Rural           In-Hearing
# ...                        ...                ...                  ...
# 2235  ANDAMAN & NICOBAR ISLAND              Urban            Any-Other
# 2236  ANDAMAN & NICOBAR ISLAND              Urban  Multiple-Disability
# 2237  ANDAMAN & NICOBAR ISLAND              Urban  Multiple-Disability
# 2238  ANDAMAN & NICOBAR ISLAND              Urban  Multiple-Disability
# 2239  ANDAMAN & NICOBAR ISLAND              Urban  Multiple-Disability
#
#            Age-group  Total disabled population - Persons  \
# ...

# %%
# Handling missing values (if any)
df.isnull().sum()
# Out:
# State Code                             0
# Area Name                              0
# Total/ Rural/Urban                     0
# Disability                             0
# Age-group                              0
# Total disabled population - Persons    0
# Total disabled population - Males      0
# Total disabled population - Females    0
# Main worker - Persons                  0
# Main worker - Males                    0
# Main worker - Females                  0
# Non-worker - Persons                   0
# Non-worker - Males                     0
# Non-worker - Females                   0
# dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Encoding categorical variables
label_encoder = LabelEncoder()
df['Disability'] = label_encoder.fit_transform(df['Disability'])
df
# Out:
#                      Area Name Total/ Rural/Urban  Disability       Age-group  \
# 0               JAMMU & KASHMI              Rural           3            0-14
# 1               JAMMU & KASHMI              Rural           3           15-59
# 2               JAMMU & KASHMI              Rural           3             60+
# 3               JAMMU & KASHMI              Rural           3  Age not stated
# 4               JAMMU & KASHMI              Rural           1            0-14
# ...                        ...                ...         ...             ...
# 2235  ANDAMAN & NICOBAR ISLAND              Urban           0  Age not stated
# 2236  ANDAMAN & NICOBAR ISLAND              Urban           7            0-14
# 2237  ANDAMAN & NICOBAR ISLAND              Urban           7           15-59
# 2238  ANDAMAN & NICOBAR ISLAND              Urban           7             60+
# 2239  ANDAMAN & NICOBAR ISLAND              Urban           7  Age not stated
#
# ...

# %%
# Splitting into features and target variable
X = df.drop(['Disability'], axis=1)  # Features
y = df['Disability']  # Target variable
X
# Out:
#       State Code                 Area Name Total/ Rural/Urban       Age-group  \
# 0              1            JAMMU & KASHMI              Rural            0-14
# 1              1            JAMMU & KASHMI              Rural           15-59
# 2              1            JAMMU & KASHMI              Rural             60+
# 3              1            JAMMU & KASHMI              Rural  Age not stated
# 4              1            JAMMU & KASHMI              Rural            0-14
# ...          ...                       ...                ...             ...
# 2235          35  ANDAMAN & NICOBAR ISLAND              Urban  Age not stated
# 2236          35  ANDAMAN & NICOBAR ISLAND              Urban            0-14
# 2237          35  ANDAMAN & NICOBAR ISLAND              Urban           15-59
# 2238          35  ANDAMAN & NICOBAR ISLAND              Urban             60+
# 2239          35  ANDAMAN & NICOBAR ISLAND              Urban  Age not stated
#
# ...

# %%
y
# Out:
# 0                 In-Seeing
# 1                 In-Seeing
# 2                 In-Seeing
# 3                 In-Seeing
# 4                In-Hearing
#                ...
# 2235              Any-Other
# 2236    Multiple-Disability
# 2237    Multiple-Disability
# 2238    Multiple-Disability
# 2239    Multiple-Disability
# Name: Disability, Length: 2240, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X['total/rural/urban_encoded'] = label_encoder.fit_transform(X['Total/ Rural/Urban'])
X
# Out:
#       State Code                 Area Name Total/ Rural/Urban       Age-group  \
# 0              1            JAMMU & KASHMI              Rural            0-14
# 1              1            JAMMU & KASHMI              Rural           15-59
# 2              1            JAMMU & KASHMI              Rural             60+
# 3              1            JAMMU & KASHMI              Rural  Age not stated
# 4              1            JAMMU & KASHMI              Rural            0-14
# ...          ...                       ...                ...             ...
# 2235          35  ANDAMAN & NICOBAR ISLAND              Urban  Age not stated
# 2236          35  ANDAMAN & NICOBAR ISLAND              Urban            0-14
# 2237          35  ANDAMAN & NICOBAR ISLAND              Urban           15-59
# 2238          35  ANDAMAN & NICOBAR ISLAND              Urban             60+
# 2239          35  ANDAMAN & NICOBAR ISLAND              Urban  Age not stated
#
# ...

# %%
# Drop the original 'total/rural/urban' column after encoding
X.drop('Total/ Rural/Urban', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X['Age-group Encoded'] = label_encoder.fit_transform(X['Age-group'])
X
# Out:
#       State Code                 Area Name       Age-group  \
# 0              1            JAMMU & KASHMI            0-14
# 1              1            JAMMU & KASHMI           15-59
# 2              1            JAMMU & KASHMI             60+
# 3              1            JAMMU & KASHMI  Age not stated
# 4              1            JAMMU & KASHMI            0-14
# ...          ...                       ...             ...
# 2235          35  ANDAMAN & NICOBAR ISLAND  Age not stated
# 2236          35  ANDAMAN & NICOBAR ISLAND            0-14
# 2237          35  ANDAMAN & NICOBAR ISLAND           15-59
# 2238          35  ANDAMAN & NICOBAR ISLAND             60+
# 2239          35  ANDAMAN & NICOBAR ISLAND  Age not stated
#
#       Total disabled population - Persons  Total disabled population - Males  \
# 0                                   10502                               5720
# 1                                   23093                              12785
# ...

# %%
X.drop('Age-group', axis=1, inplace=True)
X
# Out:
#       State Code                 Area Name  \
# 0              1            JAMMU & KASHMI
# 1              1            JAMMU & KASHMI
# 2              1            JAMMU & KASHMI
# 3              1            JAMMU & KASHMI
# 4              1            JAMMU & KASHMI
# ...          ...                       ...
# 2235          35  ANDAMAN & NICOBAR ISLAND
# 2236          35  ANDAMAN & NICOBAR ISLAND
# 2237          35  ANDAMAN & NICOBAR ISLAND
# 2238          35  ANDAMAN & NICOBAR ISLAND
# 2239          35  ANDAMAN & NICOBAR ISLAND
#
#       Total disabled population - Persons  Total disabled population - Males  \
# 0                                   10502                               5720
# 1                                   23093                              12785
# 2                                   16496                               8482
# 3                                      51                                 32
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X['Area Name Encoded'] = label_encoder.fit_transform(X['Area Name'])
X
# Out:
#       State Code                 Area Name  \
# 0              1            JAMMU & KASHMI
# 1              1            JAMMU & KASHMI
# 2              1            JAMMU & KASHMI
# 3              1            JAMMU & KASHMI
# 4              1            JAMMU & KASHMI
# ...          ...                       ...
# 2235          35  ANDAMAN & NICOBAR ISLAND
# 2236          35  ANDAMAN & NICOBAR ISLAND
# 2237          35  ANDAMAN & NICOBAR ISLAND
# 2238          35  ANDAMAN & NICOBAR ISLAND
# 2239          35  ANDAMAN & NICOBAR ISLAND
#
#       Total disabled population - Persons  Total disabled population - Males  \
# 0                                   10502                               5720
# 1                                   23093                              12785
# 2                                   16496                               8482
# 3                                      51                                 32
# ...

# %%
X.drop('Area Name', axis=1, inplace=True)
X
# Out:
#       State Code  Total disabled population - Persons  \
# 0              1                                10502
# 1              1                                23093
# 2              1                                16496
# 3              1                                   51
# 4              1                                12461
# ...          ...                                  ...
# 2235          35                                    0
# 2236          35                                   60
# 2237          35                                   88
# 2238          35                                   17
# 2239          35                                    0
#
#       Total disabled population - Males  Total disabled population - Females  \
# 0                                  5720                                 4782
# 1                                 12785                                10308
# 2                                  8482                                 8014
# ...

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
X_train
# Out:
#       State Code  Total disabled population - Persons  \
# 2001          32                                26572
# 1546          25                                    3
# 575            9                                  398
# 557            9                                90488
# 2120          34                                  102
# ...          ...                                  ...
# 1638          26                                   35
# 1095          18                                  195
# 1130          18                                  425
# 1294          21                                79780
# 860           14                                  464
#
#       Total disabled population - Males  Total disabled population - Females  \
# 2001                              14096                                12476
# 1546                                  1                                    2
# 575                                 216                                  182
# ...

# %%
y
# Out:
# 0                 In-Seeing
# 1                 In-Seeing
# 2                 In-Seeing
# 3                 In-Seeing
# 4                In-Hearing
#                ...
# 2235              Any-Other
# 2236    Multiple-Disability
# 2237    Multiple-Disability
# 2238    Multiple-Disability
# 2239    Multiple-Disability
# Name: Disability, Length: 2240, dtype: object

# %%
# Initialize the model
rf_classifier = RandomForestClassifier()

# Train the model
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predictions on the test set
predictions = rf_classifier.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")

# Classification report
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.19196428571428573
#                      precision    recall  f1-score   support
#
#           Any-Other       0.16      0.17      0.16       107
#          In-Hearing       0.17      0.13      0.15       116
#         In-Movement       0.28      0.20      0.23       119
#           In-Seeing       0.13      0.16      0.15       108
#           In-Speech       0.17      0.17      0.17       120
#      Mental-Illness       0.25      0.37      0.29       103
#  Mental-Retardation       0.16      0.15      0.16       113
# Multiple-Disability       0.22      0.20      0.21       110
#
#            accuracy                           0.19       896
#           macro avg       0.19      0.19      0.19       896
#        weighted avg       0.19      0.19      0.19       896

# %%
naive_bayes = GaussianNB()

# Train the Naive Bayes model
naive_bayes.fit(X_train, y_train)

# Predictions on the test set
predictions = naive_bayes.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")

# Classification report
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.14732142857142858
#                      precision    recall  f1-score   support
#
#           Any-Other       0.17      0.05      0.07       107
#          In-Hearing       0.10      0.01      0.02       116
#         In-Movement       0.44      0.06      0.10       119
#           In-Seeing       0.17      0.05      0.07       108
#           In-Speech       0.25      0.05      0.08       120
#      Mental-Illness       0.14      0.92      0.24       103
#  Mental-Retardation       0.12      0.03      0.04       113
# Multiple-Disability       0.14      0.09      0.11       110
#
#            accuracy                           0.15       896
#           macro avg       0.19      0.16      0.09       896
#        weighted avg       0.19      0.15      0.09       896

# %%
cm = confusion_matrix(y_test, predictions)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', cbar=False)
plt.title('Confusion Matrix - Naive Bayes')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
